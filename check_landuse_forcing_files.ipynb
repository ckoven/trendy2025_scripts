# %%
import xarray as xr

# %%
luh2_transientfile = xr.open_dataset('luh2_trendy2025_1.9x2.5_850-2024_23jun2025.nc')

# %%
luh2_transientfile['primf'].mean(dim='time').plot()

# %%
luh2_transientfile['primf'].mean(dim='lsmlon').plot(x='time',y='lsmlat')

# %%
luh2_transientfile['secdf'].mean(dim='lsmlon').plot(x='time',y='lsmlat')

# %%
luh2_steadystatefile = xr.open_dataset('LUH2_states_transitions_management.timeseries_1.9x2.5_trendy2025_steadystate_1700_2025-06-23.nc')

# %%
luh2_steadystatefile['primf'].mean(dim='time').plot()

# %%
luh2_steadystatefile['primf'].mean(dim='lsmlon').plot(x='time',y='lsmlat')

# %%
luh2_pft_file = xr.open_dataset('fates_landuse_pft_map_to_surfdata_1.9x2.5_250627.nc')

# %%
luh2_pft_file['frac_primr'].plot(x='lon',y='lat',col='natpft',col_wrap=3)

# %%
luh2_pft_file['frac_brgnd'].plot(x='lon',y='lat')

# %%
(luh2_pft_file['frac_pastr'] -luh2_pft_file['frac_primr']).plot(x='lon',y='lat',col='natpft',col_wrap=3)

# %%
(luh2_pft_file['frac_range'] -luh2_pft_file['frac_primr']).plot(x='lon',y='lat',col='natpft',col_wrap=3)
